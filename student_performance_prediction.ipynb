# %% [markdown]
# <a href="https://colab.research.google.com/github/MuntahaTazeem5/student-performance-prediction/blob/main/student_performance_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Heatmap***
#
# **Problem:** A university wants to analyze correlations between students’ study hours, attendance %, and exam scores.
#
# **Columns:** study_hours, attendance, exam_score
#
# **Steps:**
#
# Collect data from students (CSV or DataFrame).
#
# Calculate correlation matrix (.corr()).
#
# Use sns.heatmap() to visualize correlations.
#
# Check which variable has the strongest link with exam scores.

# %%
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv('/content/student_performance_dataset.csv')

# %%
data=pd.DataFrame(data)
data
# Out:
#     Student_ID  Gender  Study_Hours_per_Week  Attendance_Rate  \
# 0         S147    Male                    31        68.267841
# 1         S136    Male                    16        78.222927
# 2         S209  Female                    21        87.525096
# 3         S458  Female                    27        92.076483
# 4         S078  Female                    37        98.655517
# ..         ...     ...                   ...              ...
# 703       S492    Male                    14        84.658761
# 704       S301    Male                    35        60.278990
# 705       S473    Male                    25        98.384969
# 706       S307  Female                    21        96.148012
# 707       S046  Female                    22        80.404392
#
#      Past_Exam_Scores Parental_Education_Level Internet_Access_at_Home  \
# 0                  86              High School                     Yes
# 1                  73                      PhD                      No
# ...

# %%
data.head()
# Out:
#   Student_ID  Gender  Study_Hours_per_Week  Attendance_Rate  Past_Exam_Scores  \
# 0       S147    Male                    31        68.267841                86
# 1       S136    Male                    16        78.222927                73
# 2       S209  Female                    21        87.525096                74
# 3       S458  Female                    27        92.076483                99
# 4       S078  Female                    37        98.655517                63
#
#   Parental_Education_Level Internet_Access_at_Home Extracurricular_Activities  \
# 0              High School                     Yes                        Yes
# 1                      PhD                      No                         No
# 2                      PhD                     Yes                         No
# 3                Bachelors                      No                         No
# 4                  Masters                      No                        Yes
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 708 entries, 0 to 707
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  708 non-null    object
#  1   Gender                      708 non-null    object
#  2   Study_Hours_per_Week        708 non-null    int64
#  3   Attendance_Rate             708 non-null    float64
#  4   Past_Exam_Scores            708 non-null    int64
#  5   Parental_Education_Level    708 non-null    object
#  6   Internet_Access_at_Home     708 non-null    object
#  7   Extracurricular_Activities  708 non-null    object
#  8   Final_Exam_Score            708 non-null    int64
#  9   Pass_Fail                   708 non-null    object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 55.4+ KB

# %%
data.describe()
# Out:
#        Study_Hours_per_Week  Attendance_Rate  Past_Exam_Scores  \
# count            708.000000       708.000000        708.000000
# mean              26.132768        78.107722         77.871469
# std                8.877727        13.802802         14.402739
# min               10.000000        50.116970         50.000000
# 25%               19.000000        67.550094         65.000000
# 50%               27.000000        79.363046         79.000000
# 75%               34.000000        89.504232         91.000000
# max               39.000000        99.967675        100.000000
#
#        Final_Exam_Score
# count        708.000000
# mean          58.771186
# std            6.705877
# min           50.000000
# 25%           52.000000
# 50%           59.500000
# 75%           64.000000
# max           77.000000

# %%
import matplotlib.pyplot as plt

numeric_data = data.select_dtypes(include=['number'])
sns.heatmap(numeric_data.corr(), annot=True, fmt='.2f', cbar=True, cmap="coolwarm", square=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
correlation_with_exam_score = numeric_data.corr()['Final_Exam_Score'].sort_values(ascending=False)
print("Correlation with Final_Exam_Score:")
print(correlation_with_exam_score)
# Out:
# Correlation with Final_Exam_Score:
# Final_Exam_Score        1.000000
# Past_Exam_Scores        0.489516
# Attendance_Rate         0.460478
# Study_Hours_per_Week    0.370387
# Name: Final_Exam_Score, dtype: float64
